# %%
#1.1 Write a Python Program(with class concepts) to find the area of the triangle using the below formula.
#area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
#Function to take the length of the sides of triangle from user should be defined in the parent
#class and function to calculate the area should be defined in subclass.

class sides:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c
        
class triangle(sides):
    def __init__(self,a,b,c):
        super().__init__(a,b,c)
    
    def getarea(self):
        s=(self.a+self.b+self.c)/2
        return (s*(s-a)*(s-b)*(s-c)) ** 0.5


a=float(input("a="))
b=float(input("b="))
c=float(input("c="))
ins=triangle(a,b,c)
print("The area of the triangle is {}".format(ins.getarea()))
# Out:
# a=4
# b=5
# c=6
# The area of the triangle is 9.921567416492215

# %%
#1.2 Write a function filter_long_words() that takes a list of words and an integer n and returns
#the list of words that are longer than n.

def long_words(string,n):
    lis2=string
    lis3=[]
    for i in range(len(lis2)):
        if len(lis2[i])>n:
            lis3.append(lis2[i])
    print(lis3)
        
        
x=list(map(str,input("Enter the list of words by spaces").split()))
n=int(input("Enter the numbaer"))


long_words(x,n)
# Out:
# Enter the list of words by spacesmustakim umer
# Enter the numbaer4
# ['mustakim']

# %%
#2.1 Write a Python program using function concept that maps list of words into a list of integers
#representing the lengths of the corresponding words.
#Hint: If a list [ ab,cde,erty] is passed on to the python function output should come as [2,3,4]
#Here 2,3 and 4 are the lengths of the words in the list.




def count1(lis):
    lis2=lis
    lis3=[]
    for i in range(len(lis2)):
        lis3.append(len(lis2[i]))
    return lis3




x=list(map(str,input("Enter the list of words by spaces ").split()))


count1(x)
# Out:
# Enter the list of words by spaces sdgsg
# [5]

# %%
#2.2 Write a Python function which takes a character (i.e. a string of length 1) and returns True if
#it is a vowel, False otherwise.



def vowel(alpha):
    if alpha=='a' or alpha=='e' or alpha=='i' or alpha=='o'or alpha=='u':
        return True
    else:
        return False
    
def input_block():
        Alpha=input("Enter the alphabet ")
        x=vowel(Alpha)
        print(x)
        
        
input_block()
# Out:
# Enter the alphabet e
# True
